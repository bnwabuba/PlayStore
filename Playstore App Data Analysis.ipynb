# %% [markdown]
# # Playstore Apps analysis & Visualization

# %%
#import required libraries
import pandas as pd
import numpy as np

# %%
#Reading given files.
ps_apps = pd.read_csv(r"C:\Users\Danish\OneDrive\Desktop\Internship\Hi counsellor\playstore_apps.csv", index_col = 'App')

# %%
#displaying top 10 rows

ps_apps.head(10)
# Out:
#                                                           Category  Rating  \
# App
# Photo Editor & Candy Camera & Grid & ScrapBook      ART_AND_DESIGN     4.1
# Coloring book moana                                 ART_AND_DESIGN     3.9
# U Launcher Lite – FREE Live Cool Themes, Hide Apps  ART_AND_DESIGN     4.7
# Sketch - Draw & Paint                               ART_AND_DESIGN     4.5
# Pixel Draw - Number Art Coloring Book               ART_AND_DESIGN     4.3
# Paper flowers instructions                          ART_AND_DESIGN     4.4
# Smoke Effect Photo Maker - Smoke Editor             ART_AND_DESIGN     3.8
# Infinite Painter                                    ART_AND_DESIGN     4.1
# Garden Coloring Book                                ART_AND_DESIGN     4.4
# Kids Paint Free - Drawing Fun                       ART_AND_DESIGN     4.7
#
#                                                      Reviews  Size  \
# App
# ...

# %%
#Displaying bottom 8 rows
ps_apps.tail(8)
# Out:
#                                                           Category  Rating  \
# App
# Chemin (fr)                                    BOOKS_AND_REFERENCE     4.8
# FR Calculator                                               FAMILY     4.0
# FR Forms                                                  BUSINESS     NaN
# Sya9a Maroc - FR                                            FAMILY     4.5
# Fr. Mike Schmitz Audio Teachings                            FAMILY     5.0
# Parkinson Exercices FR                                     MEDICAL     NaN
# The SCP Foundation DB fr nn5n                  BOOKS_AND_REFERENCE     4.5
# iHoroscope - 2018 Daily Horoscope & Astrology            LIFESTYLE     4.5
#
#                                                 Reviews                Size  \
# App
# Chemin (fr)                                        44.0                619k
# FR Calculator                                       7.0                2.6M
# ...

# %%
#Describing the numerical data

ps_apps.describe().transpose()
# Out:
#             count          mean           std  min     25%       50%  \
# Rating     9367.0  4.193338e+00  5.374313e-01  1.0     4.0       4.3
# Reviews   10840.0  4.441529e+05  2.927761e+06  0.0    38.0    2094.0
# Installs  10840.0  1.546434e+07  8.502936e+07  0.0  1000.0  100000.0
# Price     10840.0  1.027368e+00  1.594970e+01  0.0     0.0       0.0
#
#                 75%           max
# Rating          4.5  1.900000e+01
# Reviews     54775.5  7.815831e+07
# Installs  5000000.0  1.000000e+09
# Price           0.0  4.000000e+02

# %%
ps_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 10841 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        10841 non-null  object
#  1   Rating          9367 non-null   float64
#  2   Reviews         10840 non-null  float64
#  3   Size            10841 non-null  object
#  4   Installs        10840 non-null  float64
#  5   Type            10840 non-null  object
#  6   Price           10840 non-null  float64
#  7   Content Rating  10840 non-null  object
#  8   Genres          10841 non-null  object
#  9   Last Updated    10840 non-null  object
#  10  Current Ver     10833 non-null  object
#  11  Android Ver     10838 non-null  object
# dtypes: float64(4), object(8)
# memory usage: 1.1+ MB

# %%
ps_apps.dtypes
# Out:
# Category           object
# Rating            float64
# Reviews           float64
# Size               object
# Installs          float64
# Type               object
# Price             float64
# Content Rating     object
# Genres             object
# Last Updated       object
# Current Ver        object
# Android Ver        object
# dtype: object

# %%
#checking for null values
ps_apps.isnull().sum()
# Out:
# Category             0
# Rating            1474
# Reviews              1
# Size                 0
# Installs             1
# Type                 1
# Price                1
# Content Rating       1
# Genres               0
# Last Updated         1
# Current Ver          8
# Android Ver          3
# dtype: int64

# %% [markdown]
# ## Subtask 1: Removing duplicate rows:

# %%
#checking for duplicate Data

ps_apps.duplicated().sum()
# Out:
# 492

# %%
ps_apps.drop_duplicates(keep = False, inplace = True)

# %%
ps_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9930 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        9930 non-null   object
#  1   Rating          8487 non-null   float64
#  2   Reviews         9929 non-null   float64
#  3   Size            9930 non-null   object
#  4   Installs        9929 non-null   float64
#  5   Type            9929 non-null   object
#  6   Price           9929 non-null   float64
#  7   Content Rating  9929 non-null   object
#  8   Genres          9930 non-null   object
#  9   Last Updated    9929 non-null   object
#  10  Current Ver     9922 non-null   object
#  11  Android Ver     9927 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 1008.5+ KB

# %% [markdown]
# ## Subtask2: Remove irrelevant values from each column if any:

# %%
#getting column names

ps_apps.columns
# Out:
# Index(['Category', 'Rating', 'Reviews', 'Size', 'Installs', 'Type', 'Price',
#        'Content Rating', 'Genres', 'Last Updated', 'Current Ver',
#        'Android Ver'],
#       dtype='object')

# %%
#checking for unique values to see if there is any irelevant data which does not match the datatype

print(ps_apps["Category"].unique())
print(ps_apps["Rating"].unique())
print(ps_apps["Reviews"].unique())
print(ps_apps["Size"].unique())
print(ps_apps["Installs"].unique())
print(ps_apps["Type"].unique())
print(ps_apps["Price"].unique())
print(ps_apps["Content Rating"].unique())
print(ps_apps["Genres"].unique())
print(ps_apps["Last Updated"].unique())
print(ps_apps["Current Ver"].unique())
print(ps_apps["Android Ver"].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION' '1.9']
# [ 4.1  3.9  4.7  4.5  4.3  4.4  3.8  4.2  4.6  3.2  4.   nan  4.8  4.9
#   3.6  3.7  3.3  3.4  3.5  3.1  5.   2.6  3.   2.5  1.   1.9  2.9  2.8
#   2.3  2.2  1.7  2.   1.8  2.7  2.4  1.6  2.1  1.4  1.5  1.2 19. ]
# [1.59000e+02 9.67000e+02 8.75100e+04 ... 6.03000e+02 1.19500e+03
#  3.98307e+05]
# ['19M' '14M' '8.7M' '25M' '2.8M' '5.6M' '29M' '33M' '3.1M' '28M' '12M'
#  '20M' '21M' '37M' '2.7M' '5.5M' '17M' '39M' '31M' '4.2M' '7.0M' '23M'
# ...

# %%
#category column has irrelevant values '1.9', type column has irrelevant value '0',.

# %%
print(ps_apps[ps_apps['Category']=='1.9'])
# Out:
#                                         Category  Rating  Reviews    Size  \
# App
# Life Made WI-Fi Touchscreen Photo Frame      1.9    19.0      NaN  1,000+
#
#                                          Installs Type  Price Content Rating  \
# App
# Life Made WI-Fi Touchscreen Photo Frame       NaN    0    NaN            NaN
#
#                                                     Genres Last Updated  \
# App
# Life Made WI-Fi Touchscreen Photo Frame  February 11, 2018          NaN
#
#                                         Current Ver Android Ver
# App
# Life Made WI-Fi Touchscreen Photo Frame  4.0 and up         NaN

# %%
ps_apps.drop("Life Made WI-Fi Touchscreen Photo Frame", inplace = True)

# %%
#checking if the data has been removed

print(ps_apps["Category"].unique())
# Out:
# ['ART_AND_DESIGN' 'AUTO_AND_VEHICLES' 'BEAUTY' 'BOOKS_AND_REFERENCE'
#  'BUSINESS' 'COMICS' 'COMMUNICATION' 'DATING' 'EDUCATION' 'ENTERTAINMENT'
#  'EVENTS' 'FINANCE' 'FOOD_AND_DRINK' 'HEALTH_AND_FITNESS' 'HOUSE_AND_HOME'
#  'LIBRARIES_AND_DEMO' 'LIFESTYLE' 'GAME' 'FAMILY' 'MEDICAL' 'SOCIAL'
#  'SHOPPING' 'PHOTOGRAPHY' 'SPORTS' 'TRAVEL_AND_LOCAL' 'TOOLS'
#  'PERSONALIZATION' 'PRODUCTIVITY' 'PARENTING' 'WEATHER' 'VIDEO_PLAYERS'
#  'NEWS_AND_MAGAZINES' 'MAPS_AND_NAVIGATION']

# %%
print(ps_apps[ps_apps['Type']== '0'])
# Out:
# Empty DataFrame
# Columns: [Category, Rating, Reviews, Size, Installs, Type, Price, Content Rating, Genres, Last Updated, Current Ver, Android Ver]
# Index: []

# %% [markdown]
# #### The above query shows empty dataframe because when I deleted the irrelevent values from Category column the irrelevant data from the Type column aslo got deleted.

# %%
ps_apps.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 9929 entries, Photo Editor & Candy Camera & Grid & ScrapBook to iHoroscope - 2018 Daily Horoscope & Astrology
# Data columns (total 12 columns):
#  #   Column          Non-Null Count  Dtype
# ---  ------          --------------  -----
#  0   Category        9929 non-null   object
#  1   Rating          8486 non-null   float64
#  2   Reviews         9929 non-null   float64
#  3   Size            9929 non-null   object
#  4   Installs        9929 non-null   float64
#  5   Type            9928 non-null   object
#  6   Price           9929 non-null   float64
#  7   Content Rating  9929 non-null   object
#  8   Genres          9929 non-null   object
#  9   Last Updated    9929 non-null   object
#  10  Current Ver     9921 non-null   object
#  11  Android Ver     9927 non-null   object
# dtypes: float64(4), object(8)
# memory usage: 1008.4+ KB

# %%
ps_apps.to_csv("cleaned_appfile.csv")
